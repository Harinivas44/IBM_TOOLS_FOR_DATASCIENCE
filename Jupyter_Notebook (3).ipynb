# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **Harinivas**
#
# student

# %% [markdown]
# _"I am interested in data science because so curious to find the hidden patterns in data and drive insights because data is wealth"

# %% [markdown]
# ### Addition of three numbers

# %%
a=int(input("Enter the 1 no:"))
b=int(input("Enter the 2 no:"))
c=int(input("Enter the 3 no:"))
print(a+b+c)
# Out:
# Enter the 1 no: 10
# Enter the 2 no: 20
# Enter the 3 no: 30
# 60

# %% [markdown]
# # Famous peoples I like
# - Elon Musk
# - Sundar Pichai
# - Cristaino Ronaldo
# - Virat Kohli
# - khabib nurmagomedov
#
# ![image.png](attachment:ed614930-0ce0-4807-a7a5-f23f8a0eff23.png)
#
# ![image.png](attachment:6289f4f2-0eb1-4089-8957-20a40a21d69b.png)
#
# ![image.png](attachment:a5d2ec38-ae03-4069-8773-809c4fe4744c.png)
#
# ![image.png](attachment:9651b22a-7a58-44cd-9edc-55ef41d770f5.png)
#
# ![image.png](attachment:35167af3-0001-4902-9589-30e285e0d227.png)
#
# https://jupyter.org/
#
# print("Hello IBM,Hello Coursera")
